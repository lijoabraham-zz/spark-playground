# %% [markdown]
# ## Spark Streaming data with Kafka
#
# For creating spark stream with kafka, we need to include an external package for kafka (spark-sql-kafka).
# We need to see the reespective version package according to the spark version we are having.
# For spark 3.0,the kafka package is spark-sql-kafka-0-10_2.12:3.0.0.
#
# You need to install kafka in the system and also for python, we need to install kafka-python package.
#
# For running kafka in local machine below are the commands to be followed.
# Go to the kafka folder in your machine. (/usr/local/kafka in my case)
#
#  - Start the zookeeper instance by using the command.
#     **( bin/zookeeper-server-start.sh config/zookeeper.properties )**
#  - Start the kafka server by using the command.
#    **( bin/kafka-server-start.sh config/server.properties )**
#  - Create a topic by using the command. **( bin/kafka-topics.sh --create --zookeeper localhost:2181 --   replication-factor 1   --partitions 1 --topic covid19 )**
#  - List the created topic with **bin/kafka-topics.sh --list --zookeeper localhost:2181**
#  - For producer- **bin/kafka-console-producer.sh --broker-list localhost:9092 --topic test-topic**
#  - For consumer - **bin/kafka-console-consumer.sh --bootstrap-server localhost:9092 --topic test-topic --from-beginning**

# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession
import os
import json
from kafka import KafkaProducer, KafkaConsumer
import requests
import time
from pyspark.sql.types import *
from pyspark.sql.functions import *

os.environ['PYSPARK_SUBMIT_ARGS'] = "--packages=org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.0 pyspark-shell"

producer = KafkaProducer(bootstrap_servers='localhost:9092')

conf = SparkConf()

spark = SparkSession.builder \
        .config(conf=conf) \
        .appName('kafka-stream') \
        .getOrCreate()
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.25.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ### Read the covid19 data from api and push it to kafka topic using python

# %%
url = "https://api.covid19india.org/travel_history.json"
consumer = KafkaConsumer(
    'numtest',
     bootstrap_servers=['localhost:9092'])

response = requests.get(url)
for i in response.json()['travel_history']:
    tDict = { key : i[key] for key in ['pid','address', 'timefrom', 'timeto']}
    producer.send('covid19',json.dumps(tDict).encode('utf-8'))
    # print(json.dumps(tDict).encode('utf-8'))
    time.sleep(100/1000)
    # break
    
fields = [
    StructField('pid',StringType(), True),
    StructField('address',StringType(), True),
    StructField('timefrom',StringType(), True),
    StructField('timeto',StringType(), True)
]
schema = StructType(fields=fields)

df = spark \
  .readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", "localhost:9092") \
  .option("subscribe", "covid19") \
  .option("startingOffsets", "latest") \
  .load()

kafka_df_string = df.selectExpr("CAST(value AS STRING)")
service_table = kafka_df_string.select(from_json(col('value'), schema).alias("covid"))
final_data = service_table.selectExpr("covid.pid","covid.address","covid.timefrom", "covid.timeto")
query = final_data.writeStream.outputMode("append").queryName("covid").format("json").option("checkpointLocation", "/tmp/checkpoint").option("parquet.block.size", "1024").start("../data/output")
query.awaitTermination()


# ds = df \
#   .selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)") \
#   .writeStream \
#   .format("console") \
#   .option("kafka.bootstrap.servers", "localhost:9092") \
#   .option("topic", "test-topic") \
#   .start()

# ds.awaitTermination()
# Out:
# b'{"pid": "P35", "address": "Hotel Aryas, Kuthattukulam, Muvattupuzha road", "timefrom": "29/02/2020 10:30:00", "timeto": "29/02/2020 11:30:00"}'
# b'{"pid": "P35", "address": "Suresh Hotel Ranni", "timefrom": "01/03/2020 21:30:00", "timeto": "01/03/2020 23:00:00"}'
# b'{"pid": "P35", "address": "Post Office Ranni Pazvangadi, Ranni", "timefrom": "02/03/2020 11:00:00", "timeto": "02/03/2020 11:30:00"}'
# b'{"pid": "P35", "address": "Knanaya Church, Pazvangadi Ranni", "timefrom": "02/03/2020 11:30:00", "timeto": "02/03/2020 12:00:00"}'
# b'{"pid": "P35", "address": "Post Office Ranni Pazvangadi", "timefrom": "02/03/2020 12:00:00", "timeto": "02/03/2020 13:00:00"}'
# b'{"pid": "P35", "address": "Golde Emporium, New Hypermarket", "timefrom": "02/03/2020 13:15:00", "timeto": "02/03/2020 14:00:00"}'
# b'{"pid": "P35", "address": "Muthoot mini supermarket, Ranni", "timefrom": "02/03/2020 14:30:00", "timeto": ""}'
# b'{"pid": "P35", "address": "Imperial Backers, Punalur", "timefrom": "02/03/2020 18:00:00", "timeto": ""}'
# b'{"pid": "P35", "address": "Relative house, Manjar PO, Punalur", "timefrom": "02/03/2020 19:00:00", "timeto": ""}'
# b'{"pid": "P35", "address": "SBI/SBT Ranni, Thottamon", "timefrom": "03/03/2020 12:00:00", "timeto": ""}'
# b'{"pid": "P35", "address": "SBI/SBT Ranni, Thottamon", "timefrom": "04/03/2020 10:00:00", "timeto": "04/03/2020 10:30:00"}'
# b'{"pid": "P35", "address": "Supreme Travels, Ranni", "timefrom": "04/03/2020 10:30:00", "timeto": "04/03/2020 11:30:00"}'
# b'{"pid": "P35", "address": "UAE Exchange Pathanamthitta", "timefrom": "05/03/2020 11:45:00", "timeto": "05/03/2020 12:15:00"}'
# b'{"pid": "P35", "address": "SP Office, Pathanamthitta", "timefrom": "05/03/2020 12:15:00", "timeto": "05/03/2020 12:45:00"}'
# b'{"pid": "P35", "address": "Royal Studio, Pathanamthitta", "timefrom": "05/03/2020 12:45:00", "timeto": "05/03/2020 13:15:00"}'
# b'{"pid": "P35", "address": "Josco Jewellery, Pathanamthitta", "timefrom": "05/03/2020 13:15:00", "timeto": "05/03/2020 14:00:00"}'
# b'{"pid": "P35", "address": "Ranni Gate Hotel, Bar", "timefrom": "05/03/2020 15:00:00", "timeto": ""}'
# b'{"pid": "P35", "address": "Admitted to Hospital. Probably Pathanamthita General Hospital", "timefrom": "06/03/2020", "timeto": ""}'
# b'{"pid": "P139", "address": "Kozhikode International Airport", "timefrom": "13/03/2020 03:30", "timeto": "13/03/2020 05:00"}'
# b'{"pid": "P139", "address": "Indian Coffe House, Nuts street, Adakkatheru, Vadakara", "timefrom": "13/03/2020 06:20", "timeto": "13/03/2020 06:50"}'
# b'{"pid": "P139", "address": "General Hospital, Mahe", "timefrom": "13/03/2020 07:00", "timeto": "13/03/2020 07:20"}'
# b'{"pid": "P139", "address": "Residence at palloor, Mahe", "timefrom": "13/03/2020 07:30", "timeto": "13/03/2020 07:30"}'
# b'{"pid": "P139", "address": "Beach Hospital, Corona Ward, Kozhikkode", "timefrom": "13/03/2020 15:30", "timeto": "13/03/2020 17:30"}'
# b'{"pid": "P139", "address": "Railway Station platform 4, Kozhikkode", "timefrom": "13/03/2020 17:50", "timeto": "13/03/2020 18:06"}'
# b'{"pid": "P139", "address": "Railway Station Platform 1, Thalasserry", "timefrom": "13/03/2020 19:09", "timeto": "13/03/2020 19:09"}'
# b'{"pid": "P139", "address": "Residence at palloor, Mahe", "timefrom": "13/03/2020 19:45", "timeto": "13/03/2020 19:45"}'
# b'{"pid": "P139", "address": "General Hospital , Mahe", "timefrom": "13/03/2020 21:45", "timeto": ""}'
# b'{"pid": "P118", "address": "Arrival at Karipur airport  ", "timefrom": "09/03/2020 08:05", "timeto": ""}'
# b'{"pid": "P118", "address": "Travel in an autocab and stopped outside relatives house at Shappinkunu", "timefrom": "09/03/2020 10:30", "timeto": ""}'
# b'{"pid": "P118", "address": "Halt at relatives house, Mattukkulam", "timefrom": "09/03/2020 11:00", "timeto": "09/03/2020 11:25"}'
# b'{"pid": "P118", "address": "Travel and halt at relatives house at Santhinagar, Vaniyambalam", "timefrom": "09/03/2020 12:00", "timeto": "09/03/2020 12:30"}'
# b'{"pid": "P118", "address": "Continued travel and reached home Santhinagar, Vaniyambalam", "timefrom": "09/03/2020 12:30", "timeto": "09/03/2020 13:00"}'
# b'{"pid": "P118", "address": "Private Medicals near Shanthi Medicals,  Wandoor", "timefrom": "09/03/2020 18:20", "timeto": "09/03/2020 18:30"}'
# b'{"pid": "P118", "address": "Nebulised at Micromax Private Lab Wandoor", "timefrom": "09/03/2020 18:30", "timeto": "09/03/2020 18:45"}'
# b'{"pid": "P118", "address": "Nebulised at Micromax Private Lab Wandoor (2nd time)", "timefrom": "10/03/2020 08:00", "timeto": "10/03/2020 08:30"}'
# b'{"pid": "P118", "address": "VMB clinic Vaniyambalam", "timefrom": "10/03/2020 12:30", "timeto": "10/03/2020 12:40"}'
# b'{"pid": "P118", "address": "Stayed at home Santhinagar, Vaniyambalam", "timefrom": "10/03/2020 13:00", "timeto": ""}'
# b'{"pid": "P118", "address": "Tavel to Talook Hospital Wandoor for consultation", "timefrom": "11/03/2020 18:30", "timeto": ""}'
# b'{"pid": "P118", "address": "Traveled back home", "timefrom": "10/03/2020 19:30", "timeto": ""}'
# b'{"pid": "P118", "address": "Stayed at home Santhinagar, Vaniyambalam", "timefrom": "12/03/2020", "timeto": ""}'
# b'{"pid": "P118", "address": "Consultation at THQ Hospital Wandoor", "timefrom": "13/03/2020 16:30", "timeto": ""}'
# b'{"pid": "P118", "address": "Reached home", "timefrom": "13/03/2020 19:30", "timeto": ""}'
# b'{"pid": "P118", "address": "Admitted at Government Medical College, Manjeri", "timefrom": "13/03/2020 20:00", "timeto": ""}'
# b'{"pid": "P43", "address": "Flight; USA to Bengaluru via Heathrow, London", "timefrom": "06/03/2020", "timeto": "08/03/2020 04:30"}'
# b'{"pid": "P43", "address": "Bengaluru Airport to Residence", "timefrom": "08/03/2020 04:30", "timeto": "08/03/2020 06:15"}'
# b'{"pid": "P43", "address": "RGICD Visit to provide test samples", "timefrom": "08/03/2020 14:30", "timeto": ""}'
# b'{"pid": "P43", "address": "Quarantined at Home", "timefrom": "08/03/2020 16:00", "timeto": "09/03/2020 20:30"}'
# b'{"pid": "P43", "address": "Taken in ambulance to RGICD", "timefrom": "09/02/2020 20:30", "timeto": ""}'
# b'{"pid": "P51", "address": "Travel from Austin, TX to New York (JFK)", "timefrom": "28/02/2020 12:30", "timeto": "28/02/2020 16:11"}'
# b'{"pid": "P51", "address": "JFK Airport, New York", "timefrom": "28/02/2020 16:11", "timeto": "28/02/2020 23:00"}'
# b'{"pid": "P51", "address": "Travel from New York to Dubai", "timefrom": "28/02/2020 23:00", "timeto": "29/02/2020 20:25"}'
# b'{"pid": "P51", "address": "Dubai Airport", "timefrom": "29/02/2020 20:25", "timeto": "01/03/2020 03:40"}'
# b'{"pid": "P51", "address": "Travel from Dubai to Bengaluru", "timefrom": "01/03/2020 03:40", "timeto": "01/03/2020 08:50"}'
# b'{"pid": "P51", "address": "Travel from Bengaluru Airport to Residence", "timefrom": "01/03/2020 09:30", "timeto": "01/03/2020 11:00"}'
# b'{"pid": "P51", "address": "Lunch at Paradise Biriyani Restaurant", "timefrom": "01/03/2020 14:00", "timeto": ""}'
# b'{"pid": "P51", "address": "Shopping at Loyal City Supermarket", "timefrom": "02/03/2020 14:00", "timeto": "02/03/2020 15:00"}'
# b'{"pid": "P51", "address": "Office - Dell, Divyasree Greens", "timefrom": "02/03/2020 16:00", "timeto": "02/03/2020 22:00"}'
# b'{"pid": "P51", "address": "Cinema, Forum Value Mall", "timefrom": "03/03/2020 10:00", "timeto": ""}'
# b'{"pid": "P51", "address": "Office - Dell, Divyasree Greens", "timefrom": "03/03/2020 14:00", "timeto": "03/03/2020 22:30"}'
# b'{"pid": "P51", "address": "RXDX Clinic for Checkup; Referred then to Manipal Hospital", "timefrom": "05/03/2020 10:30", "timeto": "05/03/2020 14:50"}'
# b'{"pid": "P51", "address": "Home", "timefrom": "05/03/2020 15:30", "timeto": "08/03/2020 14:30"}'
# b'{"pid": "P51", "address": "Mediwave Medical Store and Loyal City Supermarket", "timefrom": "08/03/2020 14:30", "timeto": "08/03/2020 15:00"}'
# b'{"pid": "P51", "address": "Home", "timefrom": "08/03/2020 15:00", "timeto": "08/03/2020 20:00"}'
# b'{"pid": "P51", "address": "Admitted to RGICD", "timefrom": "08/03/2020 20:00", "timeto": ""}'
# b'{"pid": "P38", "address": "halt at Jathanickal Cherukulangara Bakery, Ranni", "timefrom": "3/4/2020 06:00", "timeto": "3/4/2020 08:00"}'
# b'{"pid": "P38", "address": "halt at Marthoma Hospital, Ranni", "timefrom": "03/04/2020 19:00", "timeto": "03/04/2020 20:30"}'
# b'{"pid": "P38", "address": "travel by Thachilethu Bus from Ranni to Kottayam", "timefrom": "03/06/2020 08:15", "timeto": "03/06/2020 10:15"}'
# b'{"pid": "P38", "address": "halt at Palathara Textiles, Kanjikuzhy, Kottayam", "timefrom": "03/06/2020 10:30", "timeto": "03/06/2020 11:15"}'
# b'{"pid": "P38", "address": "travel by Mahiniyam bus from Kanjikuzhy to Ranni", "timefrom": "03/06/2020 14:00", "timeto": "03/06/2020 16:00"}'
# b'{"pid": "P38", "address": "Admitted to hospital", "timefrom": "8/3/2020", "timeto": ""}'
# b'{"pid": "P39", "address": "halt at Jathanickal Cherukulangara Bakery, Ranni", "timefrom": "3/4/2020 06:00", "timeto": "3/4/2020 08:00"}'
# b'{"pid": "P39", "address": "halt at Marthoma Hospital, Ranni", "timefrom": "03/04/2020 19:00", "timeto": "03/04/2020 20:30"}'
# b'{"pid": "P39", "address": "travel by Thachilethu Bus from Ranni to Kottayam", "timefrom": "03/06/2020 08:15", "timeto": "03/06/2020 10:15"}'
# b'{"pid": "P39", "address": "halt at Palathara Textiles, Kanjikuzhy, Kottayam", "timefrom": "03/06/2020 10:30", "timeto": "03/06/2020 11:15"}'
# b'{"pid": "P39", "address": "travel by Mahiniyam bus from Kanjikuzhy to Ranni", "timefrom": "03/06/2020 14:00", "timeto": "03/06/2020 16:00"}'
# b'{"pid": "P39", "address": "Admitted to hospital", "timefrom": "8/3/2020", "timeto": ""}'
# b'{"pid": "R2", "address": "Was at Hotel Aaryas on Kuthattukulum Muvattupuzha Road", "timefrom": "29/02/2020 10.30 AM", "timeto": ""}'
# b'{"pid": "R2", "address": "Relative\'s house in Punalur", "timefrom": "03/02/2020 10.30 AM", "timeto": ""}'
# b'{"pid": "R2", "address": "Shopping at Golden Hypermarket, Ranni", "timefrom": "03/03/2020 11.00 AM", "timeto": "03/03/2020 12.00 PM"}'
# b'{"pid": "R2", "address": "Was at Marthoma Private clinic, Ranni", "timefrom": "04/03/2020", "timeto": ""}'
# b'{"pid": "R2", "address": "Josco Jewellers Pathanamthitta", "timefrom": "03/05/2020 12.00 PM", "timeto": "05/03/2020 3.00 PM"}'
# b'{"pid": "R2", "address": "Hotel Rani Gate, Ranni", "timefrom": "03/05/2020 3.00 PM", "timeto": ""}'
# b'{"pid": "R2", "address": "AM Bakers Kottayam", "timefrom": "03/05/2020 8.30 PM", "timeto": "05/03/2020 9.00 PM"}'
# b'{"pid": "R2", "address": "Dr. Vinod Mani\'s clinic, Chengalam", "timefrom": "03/06/2020 10.30 AM", "timeto": ""}'
# b'{"pid": "R3", "address": "Admitted in Medical College hospital, Kottayam", "timefrom": "03/082020", "timeto": ""}'
# b'{"pid": "P42", "address": "Austin Airport US", "timefrom": "02/28/2020 12.30 PM", "timeto": ""}'
# b'{"pid": "P42", "address": "Place JFK - US, NewYork", "timefrom": "02/28/2020 4.11 PM", "timeto": "28/02/2020 11.00 PM"}'
# b'{"pid": "P42", "address": "Place Dubai", "timefrom": "02/29/2020 8.25 PM", "timeto": "29/02/2020 3.40 AM"}'
# b'{"pid": "P42", "address": "Bengaluru Airport", "timefrom": "03/1/2020 8.50 AM", "timeto": ""}'
# b'{"pid": "P42", "address": "Place: Whitefield", "timefrom": "03/1/2020 11.00 AM", "timeto": ""}'
# b'{"pid": "P42", "address": "Hotel Paradise Biryani", "timefrom": "03/1/2020 2.00 PM", "timeto": ""}'
# b'{"pid": "P42", "address": "Place Loyal City Super Market", "timefrom": "03/2/2020 2.00 PM", "timeto": "2/03/2020 3.00 PM"}'
# b'{"pid": "P42", "address": "Office: DELL Divya Shree Gardens", "timefrom": "03/2/2020 4.00 PM", "timeto": "2/03/2020 10.00 PM"}'
# b'{"pid": "P42", "address": "Movie theatre Forum Value Mall", "timefrom": "03/2/2020 10.00 AM", "timeto": ""}'
# b'{"pid": "P42", "address": "DELL Divyashree Gardens", "timefrom": "03/3/2020 2.00 PM", "timeto": "3/03/2020 10.30 PM"}'
# b'{"pid": "P42", "address": "RXDX Clinic", "timefrom": "03/5/2020 10.30 AM", "timeto": ""}'
# b'{"pid": "P42", "address": "Referred to Manipal Hospital", "timefrom": "03/5/2020 2.50 PM", "timeto": ""}'
# b'{"pid": "P42", "address": "Home, Whitefield", "timefrom": "03/5/2020 3.30 PM", "timeto": ""}'
# b'{"pid": "P42", "address": "Home, Whitefield", "timefrom": "03/06/2020", "timeto": "07/03/2020"}'
# b'{"pid": "P42", "address": "Place: Medway Medical store and Loyal City Market", "timefrom": "03/8/2020 2.30 PM", "timeto": ""}'
# b'{"pid": "P42", "address": "Home, Whitefield", "timefrom": "03/8/2020 3.00", "timeto": ""}'
# b'{"pid": "P42", "address": "Admitted to RGICD", "timefrom": "03/8/2020 8.00 pm", "timeto": ""}'
# b'{"pid": "P73", "address": "Mumbai Airport from Greece", "timefrom": "03/06/2020 11.55 PM", "timeto": ""}'
# b'{"pid": "P73", "address": "Mumbai Home", "timefrom": "03/06/2020", "timeto": ""}'
# b'{"pid": "P73", "address": "Place: Bangalore. Travelled in taxi and reahed home", "timefrom": "03/08/2020 9.45 PM", "timeto": "03/08/2020 23:30"}'
# b'{"pid": "P73", "address": "Home", "timefrom": "03/09/2020", "timeto": ""}'
# b'{"pid": "P73", "address": "Visited RGCID and sample was sent to NIV", "timefrom": "03/10/2020 5.55 PM", "timeto": ""}'
# b'{"pid": "P73", "address": "Patient was shifted to Jayanagar General Hospital and admitted", "timefrom": "03/11/2020 8.30 PM", "timeto": ""}'
# b'{"pid": "P73", "address": "BBMP surveillance team is doing surveillance", "timefrom": "03/12/2020", "timeto": ""}'
# b'{"pid": "P87", "address": "London Flight No. GF2", "timefrom": "03/10/2020", "timeto": ""}'
# b'{"pid": "P87", "address": "Bahrain Flight No. GF0060", "timefrom": "03/10/2020", "timeto": ""}'
# b'{"pid": "P87", "address": "Trivandram International Airport", "timefrom": "03/10/2020 5.00 AM", "timeto": ""}'
# b'{"pid": "P87", "address": "Travelled by own car to Artech Square Kaithamukku, Pettah", "timefrom": "03/10/2020 5.45 AM", "timeto": ""}'
# b'{"pid": "P87", "address": "Travelled to General hospital, Trivandram by own car", "timefrom": "03/11/2020 8.00 AM", "timeto": ""}'
# b'{"pid": "P87", "address": "Walked to car parking area, General Hospital, Trivandram", "timefrom": "03/11/2020", "timeto": ""}'
# b'{"pid": "P87", "address": "Walked to OP ticket counter walking area GH Trivandram", "timefrom": "03/11/2020", "timeto": ""}'
# b'{"pid": "P87", "address": "COVID 19 OP Walking area", "timefrom": "03/11/2020", "timeto": ""}'
# b'{"pid": "P87", "address": "Isolation ward", "timefrom": "03/11/2020", "timeto": ""}'
# b'{"pid": "P87", "address": "General hospital front gate by auto", "timefrom": "03/11/2020 10.30 AM", "timeto": ""}'
# b'{"pid": "P87", "address": "2 shops at Kaithamukku Opp.Co-operative bank", "timefrom": "03/11/2020", "timeto": ""}'
# b'{"pid": "P87", "address": "Artech Square Security point", "timefrom": "03/11/2020", "timeto": ""}'
# b'{"pid": "P87", "address": "Artech Square", "timefrom": "03/11/2020 10.45 AM", "timeto": ""}'
# b'{"pid": "P87", "address": "reached Medical college hospital isolation ward through ambulance", "timefrom": "03/11/2020 16:00", "timeto": ""}'
# b'{"pid": "P1", "address": "Flight No: SG54 SPICE JET,Calicut Airport", "timefrom": "05.03.2020 9:30PM", "timeto": "05.03.2020 11:00PM"}'
# b'{"pid": "P1", "address": "Hotel Malabar Plaza\\n(Near Ramanattukara)", "timefrom": "05.03.2020 11.15 PM", "timeto": "05.03.2020 11.45 PM"}'
# b'{"pid": "P1", "address": "Travel on road by \\ntaxi", "timefrom": "05.03.2020 11.45 PM", "timeto": "06.03.2020 04:00 AM"}'
# b'{"pid": "P1", "address": "Patient Home \\n( Home quarantine)", "timefrom": "06.03.2020 04:00 AM", "timeto": "07.03.2020 02:30pm"}'
# b'{"pid": "P1", "address": "Private Consultation \\n(Dr Home) \\nLocation: Mathil", "timefrom": "07.03.2020 02:30 PM", "timeto": "07.03.2020 02:40 PM"}'
# b'{"pid": "P1", "address": "On road by private car", "timefrom": "07.03.2020 02:45 PM", "timeto": "07.03.2020 03:00 PM"}'
# b'{"pid": "P1", "address": "Casuality,GMC Kannur", "timefrom": "07.03.2020 03:30 PM", "timeto": "07.03.2020 03:35 PM"}'
# b'{"pid": "P1", "address": "Isolation unit, GMC Kannur", "timefrom": "07.03.2020 03:35 PM", "timeto": "08.03.2020 12:00 AM"}'
# b'{"pid": "P1", "address": "Hospital Isolation, GMC Kannur", "timefrom": "08.03.2020 12:00 AM", "timeto": "08.03.2020 12:00 PM"}'
# b'{"pid": "P1", "address": "Hospital Isolation, GMC Kannur", "timefrom": "09.03.2020 12:00 AM", "timeto": "09.03.2020 12:00 PM"}'
# b'{"pid": "P1", "address": "Hospital Isolation, GMC Kannur", "timefrom": "10.03.2020 12:00AM", "timeto": "10.03.2020 04:00 PM"}'
# b'{"pid": "P1", "address": "Travel by private \\ncar", "timefrom": "10.03.2020 04:00 PM", "timeto": "10.03.2020 05:00 PM"}'
# b'{"pid": "P1", "address": "Patient reached his Home \\n(Isolation)", "timefrom": "10.03.2020 05:00 PM", "timeto": "11.03.2020 12:00 AM"}'
# b'{"pid": "P1", "address": "Strict Home isolation", "timefrom": "11.03.2020 12:00 AM", "timeto": "11.03.2020 12:00 PM"}'
# b'{"pid": "P1", "address": "Strict Home isolation", "timefrom": "12.03.2020 12:00 AM", "timeto": "12.03.2020 09:00 PM"}'
# b'{"pid": "P1", "address": "Travelling in \\nAmbulance \\nby road", "timefrom": "12.03.2020 09:00 PM", "timeto": "12.03.2020 10:00 PM"}'
# b'{"pid": "P1", "address": "Patient reached Isolation ward, GMC Kannur", "timefrom": "12.03.2020 10:00 PM", "timeto": ""}'
# b'{"pid": "P4", "address": "Bangalore Airport - Came from USA through London,Heathrow", "timefrom": "08.03.2020 04:30 AM", "timeto": "08.03.2020 06:15 AM"}'
# b'{"pid": "P4", "address": "HOME", "timefrom": "08.03.2020 06:15 AM", "timeto": "08.03.2020 02:30 PM"}'
# b'{"pid": "P4", "address": "Visited RGICD at 02:30pm and sample was collected and sent to NIV Bangalore", "timefrom": "08.03.2020 02:30 PM", "timeto": "08.03.2020 02:30 PM"}'
# b'{"pid": "P4", "address": "Whole day he was under home quarantine", "timefrom": "09:03.2020 12:00 AM", "timeto": "09.03.2020 08:30 PM"}'
# b'{"pid": "P4", "address": "Travlled through Ambulance and got admitted to RGICD,Bangalore", "timefrom": "09.03.2020 08:30 PM", "timeto": ""}'
# b'{"pid": "P6", "address": "Hyderabad airport and travelled to Kalburgi.", "timefrom": "29:02:2020 12:30 PM", "timeto": "29:02:2020 05:00 PM"}'
# b'{"pid": "P7", "address": "Had fever and family physician visited and gave treatment", "timefrom": "06.03.2020", "timeto": ""}'
# b'{"pid": "P8", "address": "Treated at home by family doctor then shifted to private hospital and got admitted,\\nSample was collected and was sent to VRDL,BMC & RI\\nPatient was discharged against medical advise at 10:00 PM", "timefrom": "09.03.2020 10:00 AM", "timeto": "09.03.2020 10:00 PM"}'
# b'{"pid": "P109", "address": "Arrived at Trivandrum\\nFlight QR506\\nDoha to TVM", "timefrom": "02.03.2020 01:20AM", "timeto": ""}'
# b'{"pid": "P110", "address": "Ulloor Gardens", "timefrom": "02.03.2020", "timeto": ""}'
# b'{"pid": "P111", "address": "Hotel Bismi, Kumarapuram", "timefrom": "02.03.2020 06:00 PM", "timeto": "02.03.2020 06:30 PM"}'
# b'{"pid": "P112", "address": "Hotel Ambadi Kannan,Medical College Junction", "timefrom": "03.03.2020 07:30 PM", "timeto": ""}'
# b'{"pid": "P113", "address": "Hotel Bismi, Kumarapuram", "timefrom": "04.03.2020 06:00 PM", "timeto": ""}'
# b'{"pid": "P114", "address": "Hotel Thamarassery Churam", "timefrom": "05.03.2020 06:00 PM", "timeto": ""}'
# b'{"pid": "P115", "address": "Margin free market,Kunnil,Medical College Junction", "timefrom": "08.03.2020 07:30 PM", "timeto": "08.03.2020 08:30 PM"}'
# b'{"pid": "P117", "address": "Hotel Kochi Pedia", "timefrom": "11.03.2020 05:00 PM", "timeto": "11:03:2020 06:00 PM"}'
# b'{"pid": "P36", "address": "Suresh Hotel, Ranni", "timefrom": "03/01/2020 21:30", "timeto": "03/01/2020 23:00"}'
# b'{"pid": "P36", "address": "Mini Shopee, Ranni", "timefrom": "03/02/2020 09:50", "timeto": "03/02/2020 10:10"}'
# b'{"pid": "P36", "address": "HP Petrol Pump, Ranni", "timefrom": "03/02/2020 10:15", "timeto": "3/2/2020 10:20:00"}'
# b'{"pid": "P36", "address": "Ittiyapara Bus Stand, Ranni", "timefrom": "03/02/2020 10:25", "timeto": "3/2/2020 10:25:00"}'
# b'{"pid": "P36", "address": "Post Office, Ranni, Pazhavangadi", "timefrom": "03/02/2020 11:00", "timeto": "3/2/2020 11:30:00"}'
# b'{"pid": "P36", "address": "Knanaya Church, Ranni, Pazhavangadi", "timefrom": "3/2/2020 11:30:00", "timeto": "3/2/2020 12:00:00"}'
# b'{"pid": "P36", "address": "Post Office, Ranni, Pazhavangadi", "timefrom": "3/2/2020 12:00:00", "timeto": "3/2/2020 13:00:00"}'
# b'{"pid": "P36", "address": "Golden Emporium, New Hypermarket, Ranni", "timefrom": "3/2/2020 13:15:00", "timeto": "3/2/2020 14:00:00"}'
# b'{"pid": "P36", "address": "Mini Shopee, Ranni", "timefrom": "3/2/2020 14:30:00", "timeto": "3/2/2020 14:30:00"}'
# b'{"pid": "P36", "address": "Imperial Bakery, Punalur", "timefrom": "3/2/2020 18:00:00", "timeto": "3/2/2020 18:00:00"}'
# b'{"pid": "P36", "address": "Maniyar, Punalur", "timefrom": "3/2/2020 19:00:00", "timeto": "3/2/2020 19:00:00"}'
# b'{"pid": "P36", "address": "Mini Shopee, Ranni", "timefrom": "3/3/2020 10:00:00", "timeto": "3/3/2020 10:00:00"}'
# b'{"pid": "P36", "address": "SBI/SBT, Ranni, Thottamon", "timefrom": "3/3/2020 10:30:00", "timeto": "3/3/2020 10:30:00"}'
# b'{"pid": "P36", "address": "ESAF Bank, Ranni", "timefrom": "3/3/2020 11:00:00", "timeto": "3/3/2020 11:00:00"}'
# b'{"pid": "P36", "address": "Grama Panchayat, Ranni, Pazhavangadi", "timefrom": "3/3/2020 11:35:00", "timeto": "3/3/2020 11:50:00"}'
# b'{"pid": "P36", "address": "SBI/SBT, Ranni, Thottamon", "timefrom": "3/3/2020 12:00:00", "timeto": "3/3/2020 12:00:00"}'
# b'{"pid": "P36", "address": "Grand Bakery, Ranni, Ittypara", "timefrom": "3/3/2020 12:35:00", "timeto": "3/3/2020 12:45:00"}'
# b'{"pid": "P36", "address": "SBI/SBT, Ranni, Thottamon", "timefrom": "3/4/2020 10:00:00", "timeto": "3/4/2020 10:30:00"}'
# b'{"pid": "P36", "address": "Supreme Travels, Ranni", "timefrom": "3/4/2020 10:30:00", "timeto": "3/4/2020 11:30:00"}'
# b'{"pid": "P36", "address": "Marthoma Hospital, Ranni", "timefrom": "3/4/2020 20:20:00", "timeto": "3/4/2020 20:20:00"}'
# b'{"pid": "P36", "address": "Baby Palace, Ranni, Ittiyapara", "timefrom": "3/5/2020 11:30:00", "timeto": "3/5/2020 11:45:00"}'
# b'{"pid": "P36", "address": "Unimoni/ UAE Exchange, Ranni", "timefrom": "3/5/2020 11:45:00", "timeto": "3/5/2020 12:00:00"}'
# b'{"pid": "P36", "address": "SP Office, Pathanamthitta", "timefrom": "3/5/2020 12:15:00", "timeto": "3/5/2020 12:45:00"}'
# b'{"pid": "P36", "address": "Royal Studio, Pathanamthitta", "timefrom": "3/5/2020 12:45:00", "timeto": "3/5/2020 13:15:00"}'
# b'{"pid": "P36", "address": "Josco Jewlerry", "timefrom": "3/5/2020 13:15:00", "timeto": "3/5/2020 14:00:00"}'
# b'{"pid": "P36", "address": "Ranni Gate Hospital", "timefrom": "3/5/2020 15:00:00", "timeto": "3/5/2020 15:00:00"}'
# b'{"pid": "P37", "address": "Hotel Aryas, Kuthattukulam, Muvattupuzha Road", "timefrom": "02/29/2020 10:30", "timeto": "02/29/2020 11:30"}'
# b'{"pid": "P37", "address": "Suresh Hotel, Ranni", "timefrom": "03/01/2020 21:30", "timeto": "03/01/2020 23:00"}'
# b'{"pid": "P37", "address": "Mini Shopee, Ranni", "timefrom": "03/02/2020 09:50", "timeto": "03/02/2020 10:10"}'
# b'{"pid": "P37", "address": "HP Petrol Pump, Ranni", "timefrom": "03/02/2020 10:15", "timeto": "3/2/2020 10:20:00"}'
# b'{"pid": "P37", "address": "Ittiyapara Bus Stand, Ranni", "timefrom": "03/02/2020 10:25", "timeto": "3/2/2020 10:25:00"}'
# b'{"pid": "P37", "address": "Post Office, Ranni, Pazhavangadi", "timefrom": "03/02/2020 11:00", "timeto": "3/2/2020 11:30:00"}'
# b'{"pid": "P37", "address": "Knanaya Church, Ranni, Pazhavangadi", "timefrom": "3/2/2020 11:30:00", "timeto": "3/2/2020 12:00:00"}'
# b'{"pid": "P37", "address": "Post Office, Ranni, Pazhavangadi", "timefrom": "3/2/2020 12:00:00", "timeto": "3/2/2020 13:00:00"}'
# b'{"pid": "P37", "address": "Golden Emporium, New Hypermarket, Ranni", "timefrom": "3/2/2020 13:15:00", "timeto": "3/2/2020 14:00:00"}'
# b'{"pid": "P37", "address": "Mini Shopee, Ranni", "timefrom": "3/2/2020 14:30:00", "timeto": "3/2/2020 14:30:00"}'
# b'{"pid": "P37", "address": "Imperial Bakery, Punalur", "timefrom": "3/2/2020 18:00:00", "timeto": "3/2/2020 18:00:00"}'
# b'{"pid": "P37", "address": "Maniyar, Punalur", "timefrom": "3/2/2020 19:00:00", "timeto": "3/2/2020 19:00:00"}'
# b'{"pid": "P37", "address": "Mini Shopee, Ranni", "timefrom": "3/3/2020 10:00:00", "timeto": "3/3/2020 10:00:00"}'
# b'{"pid": "P37", "address": "SBI/SBT, Ranni, Thottamon", "timefrom": "3/3/2020 10:30:00", "timeto": "3/3/2020 10:30:00"}'
# b'{"pid": "P37", "address": "ESAF Bank, Ranni", "timefrom": "3/3/2020 11:00:00", "timeto": "3/3/2020 11:00:00"}'
# b'{"pid": "P37", "address": "Grama Panchayat, Ranni, Pazhavangadi", "timefrom": "3/3/2020 11:35:00", "timeto": "3/3/2020 11:50:00"}'
# b'{"pid": "P37", "address": "SBI/SBT, Ranni, Thottamon", "timefrom": "3/3/2020 12:00:00", "timeto": "3/3/2020 12:00:00"}'
# b'{"pid": "P37", "address": "Grand Bakery, Ranni, Ittypara", "timefrom": "3/3/2020 12:35:00", "timeto": "3/3/2020 12:45:00"}'
# b'{"pid": "P37", "address": "SBI/SBT, Ranni, Thottamon", "timefrom": "3/4/2020 10:00:00", "timeto": "3/4/2020 10:30:00"}'
# b'{"pid": "P37", "address": "Supreme Travels, Ranni", "timefrom": "3/4/2020 10:30:00", "timeto": "3/4/2020 11:30:00"}'
# b'{"pid": "P37", "address": "Marthoma Hospital, Ranni", "timefrom": "3/4/2020 20:20:00", "timeto": "3/4/2020 20:20:00"}'
# b'{"pid": "P37", "address": "Baby Palace, Ranni, Ittiyapara", "timefrom": "3/5/2020 11:30:00", "timeto": "3/5/2020 11:45:00"}'
# b'{"pid": "P37", "address": "Unimoni/ UAE Exchange, Ranni", "timefrom": "3/5/2020 11:45:00", "timeto": "3/5/2020 12:00:00"}'
# b'{"pid": "P37", "address": "SP Office, Pathanamthitta", "timefrom": "3/5/2020 12:15:00", "timeto": "3/5/2020 12:45:00"}'
# b'{"pid": "P37", "address": "Royal Studio, Pathanamthitta", "timefrom": "3/5/2020 12:45:00", "timeto": "3/5/2020 13:15:00"}'
# b'{"pid": "P37", "address": "Josco Jewlerry", "timefrom": "3/5/2020 13:15:00", "timeto": "3/5/2020 14:00:00"}'
# b'{"pid": "P37", "address": "Ranni Gate Hospital", "timefrom": "3/5/2020 15:00:00", "timeto": "3/5/2020 15:00:00"}'
# b'{"pid": "P116", "address": "Met father at Fathers House Near KNZ Function hall, Kalaburagi", "timefrom": "02/29/2020 0:00", "timeto": "02/29/2020 0:00"}'
# b'{"pid": "P116", "address": "Stayed at own house Fort", "timefrom": "03/01/2020 00:00", "timeto": "03/02/2020 00:00"}'
# b'{"pid": "P116", "address": "Met father at Fathers House Near KNZ Function hall, Kalaburagi", "timefrom": "03/03/2020 00:00", "timeto": "03/03/2020 00:00"}'
# b'{"pid": "P116", "address": "Stayed at own house Fort", "timefrom": "03/04/2020 00:00", "timeto": "03/05/2020 00:00"}'
# b'{"pid": "P116", "address": "Met father at Fathers House Near KNZ Function hall, Kalaburagi", "timefrom": "03/06/2020 00:00", "timeto": "03/06/2020 00:00"}'
# b'{"pid": "P116", "address": "Stayed at own house Fort", "timefrom": "03/07/2020 00:00", "timeto": "03/08/2020 00:00"}'
# b'{"pid": "P116", "address": "Accompanied patient 6 (father) in ambulance during his illness from Hyderabad to Kalaburagi", "timefrom": "03/09/2020 00:00", "timeto": "03/09/2020 00:00"}'
# b'{"pid": "P116", "address": "stayed at fathers house Near KNZ Function Hall, Kalaburagi", "timefrom": "03/10/2020 00:00", "timeto": "03/10/2020 00:00"}'
# b'{"pid": "P116", "address": "Admitted to ESI Hospital Kalaburagi", "timefrom": "03/11/2020 00:00", "timeto": ""}'
# b'{"pid": "P119", "address": "Arrival at Nedumbassery Airport by AirIndia Flight no AI964 (JEDDAH-KOCHI)", "timefrom": "03/12/2020 07:30", "timeto": "03/12/2020 09:30"}'
# b'{"pid": "P119", "address": "Started travel from Airport in Benzy travels bus with approximate 40 Travellers", "timefrom": "03/12/2020 09:30", "timeto": "03/12/2020 15:30"}'
# b'{"pid": "P119", "address": "Reached Busstop near Hajj House Karipur", "timefrom": "03/12/2020 15:30", "timeto": "03/12/2020 15:30"}'
# b'{"pid": "P119", "address": "Travel to home", "timefrom": "03/12/2020 15:30", "timeto": "03/12/2020 16:00"}'
# b'{"pid": "P119", "address": "Reached home at Chemrakkattil Vellari, Areakode", "timefrom": "03/12/2020 16:00", "timeto": ""}'
# b'{"pid": "P119", "address": "Consultation at Areecode Thaluk Hospital", "timefrom": "03/13/2020 10:10", "timeto": "03/13/2020 10:20"}'
# b'{"pid": "P119", "address": "Return Home", "timefrom": "03/13/2020 11:00", "timeto": "03/13/2020 11:00"}'
# b'{"pid": "P119", "address": "Admitted at Government Medical college, Manjeri", "timefrom": "03/13/2020 14:00", "timeto": ""}'
# b'{"pid": "P175", "address": "Reached Kempegowda Intl Airport by Indigo Flight no 6E96(Dubai - Banglore)", "timefrom": "03/15/2020 16:15", "timeto": ""}'
# b'{"pid": "P175", "address": "Took KSRTC Rajahamsa Bus(KA 19 F 3170) from Satellite Bus Stand to Madikeri (via Virajpet and Muranad)", "timefrom": "03/15/2020 23:33", "timeto": ""}'
# b'{"pid": "P175", "address": "Tested COVID-19 positive in Kodagu", "timefrom": "03/19/2020 0:00", "timeto": ""}'
# b'{"pid": "P52", "address": "Travel from airport to Paradie Biryani Whitefield", "timefrom": "03/01/2020 13:00", "timeto": "03/01/2020 14:00"}'
# b'{"pid": "P52", "address": "Paradise Biryani, Whitefield", "timefrom": "03/01/2020 14:00", "timeto": "03/01/2020 14:00"}'
# b'{"pid": "P52", "address": "Met friend in her apartment", "timefrom": "03/01/2020 17:30", "timeto": "03/01/2020 17:30"}'
# b'{"pid": "P52", "address": "Walk in apartment with friend", "timefrom": "03/02/2020 17:30", "timeto": "03/02/2020 17:30"}'
# b'{"pid": "P52", "address": "Movie at Forum Valley Mall", "timefrom": "03/03/2020 10:00", "timeto": "03/03/2020 13:00"}'
# b'{"pid": "P52", "address": "Walk in apartment with friend", "timefrom": "03/03/2020 17:30", "timeto": "03/03/2020 18:00"}'
# b'{"pid": "P52", "address": "Walk in apartment with friend", "timefrom": "03/07/2020 17:30", "timeto": "03/07/2020 18:00"}'
# b'{"pid": "P52", "address": "Bought medicine at Mediwave", "timefrom": "03/08/2020 14:30", "timeto": "03/08/2020 15:00"}'
# b'{"pid": "P52", "address": "Met Dhobi in apartment", "timefrom": "03/08/2020 20:30", "timeto": "03/08/2020 20:30"}'
# b'{"pid": "P52", "address": "Admitted in RJICD", "timefrom": "03/08/2020 20:30", "timeto": "03/08/2020 20:30"}'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ce528ac6b8b5> in <module>
#      42 query = final_data.writeStream.outputMode("append").queryName("covid").format("json").option("checkpointLocation", "/tmp/checkpoint").option("parquet.block.size", "1024").start("../data/output")
#      43 # final_data.write.save(path='../data/covid.txt', format='txt', mode='append', sep='\t')
# ---> 44 query.awaitTermination()
#      45
#      46 # ds = df \
#
# /usr/local/lib/python3.6/dist-packages/pyspark/sql/streaming.py in awaitTermination(self, timeout)
#     101             return self._jsq.awaitTermination(int(timeout * 1000))
#     102         else:
# --> 103             return self._jsq.awaitTermination()
#     104
#     105     @property
#
# /usr/local/lib/python3.6/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1301             proto.END_COMMAND_PART
#    1302
# -> 1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/local/lib/python3.6/dist-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1031         connection = self._get_connection()
#    1032         try:
# -> 1033             response = connection.send_command(command)
#    1034             if binary:
#    1035                 return response, self._create_connection_guard(connection)
#
# /usr/local/lib/python3.6/dist-packages/py4j/java_gateway.py in send_command(self, command)
#    1198
#    1199         try:
# -> 1200             answer = smart_decode(self.stream.readline()[:-1])
#    1201             logger.debug("Answer received: {0}".format(answer))
#    1202             if answer.startswith(proto.RETURN_MESSAGE):
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Read the output data written on the folder

# %%
jsonData = spark.read.json("../data/output/*.json")
jsonData.show(2)
# Out:
# +--------------------+---+-------------------+-------------------+
# |             address|pid|           timefrom|             timeto|
# +--------------------+---+-------------------+-------------------+
# |Hotel Aryas, Kuth...|P35|29/02/2020 10:30:00|29/02/2020 11:30:00|
# |  Suresh Hotel Ranni|P35|01/03/2020 21:30:00|01/03/2020 23:00:00|
# +--------------------+---+-------------------+-------------------+
# only showing top 2 rows
